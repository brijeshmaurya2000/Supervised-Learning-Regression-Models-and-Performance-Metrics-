# %% [markdown]
# Question 1 : What is Simple Linear Regression (SLR)? Explain its purpose.
#
#
# - Simple Linear Regression (SLR) is a statistical method used to model the relationship between two quantitative variables — one independent variable (X) and one dependent variable (Y).
#
#    The goal is to determine a linear equation that best predicts the value of
# 𝑌
# Y based on
# 𝑋
# X.
#
#  - Mathematical Form
# 𝑌
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# +
# 𝜀
# Y=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X+ε
#
# Where:
#
# 𝑌
# Y: Dependent (response) variable
#
# 𝑋
# X: Independent (predictor) variable
#
# 𝛽
# 0
# β
# 0
# 	​
#
# : Intercept (value of
# 𝑌
# Y when
# 𝑋
# =
# 0
# X=0)
#
# 𝛽
# 1
# β
# 1
# 	​
#
# : Slope (change in
# 𝑌
# Y for a one-unit change in
# 𝑋
# X)
#
# 𝜀
# ε: Random error term (captures deviations not explained by
# 𝑋
# X)
#  -  Purpose of SLR
#
# Prediction:
# To predict the value of the dependent variable
# 𝑌
# Y based on the known value of
# 𝑋
# X.
# Example: Predicting a student’s exam score based on hours studied.
#
# Understanding Relationships:
# To measure the strength and direction of the relationship between
# 𝑋
# X and
# 𝑌
# Y.
#
# Positive slope (
# 𝛽
# 1
# >
# 0
# β
# 1
# 	​
#
# >0):
# 𝑌
# Y increases as
# 𝑋
# X increases.
#
# Negative slope (
# 𝛽
# 1
# <
# 0
# β
# 1
# 	​
#
# <0):
# 𝑌
# Y decreases as
# 𝑋
# X increases.
#
# Quantifying Effects:
# To determine how much
# 𝑌
# Y changes, on average, for a one-unit change in
# 𝑋
# X.

# %% [markdown]
# Question 2: What are the key assumptions of Simple Linear Regression?
#
#  - Key Assumptions of Simple Linear Regression (SLR):
#
#  - To ensure that the results of a simple linear regression are valid and reliable, several statistical assumptions must be met. These assumptions relate to the relationship between the independent variable
# 𝑋
# X and the dependent variable
# 𝑌
# Y, as well as the behavior of the residuals (errors).
#
# -  1. Linearity
#
#  - The relationship between the independent variable
# 𝑋
# X and the dependent variable
# 𝑌
# Y is linear.
#
# ##Mathematically:
#
# 𝐸
# (
# 𝑌
# ∣
# 𝑋
# )
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# E(Y∣X)=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X
#
# Meaning: The change in
# 𝑌
# Y is proportional to the change in
# 𝑋
# X.
#
# Check: Use a scatter plot of
# 𝑌
# Y vs.
# 𝑋
# X — it should form roughly a straight line.
#
#  - 2. Independence of Errors
#
# The residuals (errors) are independent of each other.
#
# Meaning: The value of one error term should not influence another.
#
# Check: Often tested using the Durbin–Watson test (especially for time-series data).
#
#  -  3. Homoscedasticity (Constant Variance of Errors)
#
# The residuals have constant variance across all levels of
# 𝑋
# X.
#
# Meaning: The spread (variance) of errors should be roughly the same for all predicted values.
#
# Check: Plot residuals vs. fitted values — the spread should be uniform (no funnel shape).
#
#  - 4. Normality of Errors
#
# The residuals (errors) are normally distributed.
#
# Meaning: When plotted as a histogram or a Q–Q plot, residuals should approximate a normal curve.
#
# Importance: This assumption is crucial for valid hypothesis testing and confidence intervals.
#
#  - 5. No Perfect Multicollinearity
#
# Since SLR uses only one independent variable, this assumption is automatically satisfied.
#
# However, it becomes important in multiple regression.
#  -  6. No Measurement Error in X
#
# The independent variable
# 𝑋
# X is measured without error (or with minimal error).
#
# Measurement errors in
# 𝑋
# X can bias the slope estimate (
# 𝛽
# 1
# β
# 1
# 	​
#
# ).

# %% [markdown]
# Question 3: Write the mathematical equation for a simple linear regression model and
# explain each term.
#
#  - Mathematical Equation of a Simple Linear Regression (SLR) Model
# 𝑌
# 𝑖
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# 𝑖
# +
# 𝜀
# 𝑖
# Y
# i
# 	​
#
# =β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X
# i
# 	​
#
# +ε
# i
# 	​

# %% [markdown]
# Question 4: Provide a real-world example where simple linear regression can be
# applied.
#
#  - Real-World Example of Simple Linear Regression (SLR)
#
# ##Scenario:
#  - A company wants to predict sales revenue based on its advertising expenditure.
#
# ##Example Explanation
#
#  - Dependent Variable (Y): Sales Revenue (in dollars)
#
#  - Independent Variable (X): Advertising Expenditure (in dollars)
#
#  - The company collects data for several months:
#
# Month	Advertising (X)	Sales (Y)
# 1	1,000	15,000
# 2	2,000	20,000
# 3	3,000	25,000
# 4	4,000	28,000
#
#  - Using simple linear regression, the company fits a model:
#
# 𝑌
# ^
# =
# 12
# ,
# 000
# +
# 4
# 𝑋
# Y
# ^
# =12,000+4X
# Interpretation
#
# Intercept (
# 𝛽
# 0
# =
# 12
# ,
# 000
# β
# 0
# 	​
#
# =12,000):
# Even with no advertising, the company expects baseline sales of 12,000 (perhaps due to loyal customers).
#
# Slope (
# 𝛽
# 1
# =
# 4
# β
# 1
# 	​
#
# =4):
# For every 1 increase in advertising, sales are expected to increase by 4 on average.
#
# ##Purpose / Usefulness
#
# ##Prediction:
#
#  -Estimate future sales for a given advertising budget.
#
# ##Example:
#
#  - If the company plans to spend 3,500 on ads →
#
# 𝑌
# ^
# =
# 12
# ,
# 000
# +
# 4
# (
# 3
# ,
# 500
# )
# =
# 26
# ,
# 000
# Y
# ^
# =12,000+4(3,500)=26,000
#
# → Predicted Sales = 26,000
#
# Decision-Making: Helps managers decide how much to invest in advertising to achieve desired sales.
#
# Understanding Relationships: Quantifies how strongly advertising impacts sales performance.

# %% [markdown]
# Question 5: What is the method of least squares in linear regression?
#
#  - Method of Least Squares in Linear Regression
#
#  - The method of least squares is the most common technique used to estimate the parameters (slope and intercept) of a simple linear regression model.
#
#  - It finds the best-fitting straight line through a set of data points by minimizing the sum of the squared differences between the observed values and the values predicted by the line.
#
# ##Mathematical Formulation
#
#  - The simple linear regression model is:
#
# 𝑌
# 𝑖
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# 𝑖
# +
# 𝜀
# 𝑖
# Y
# i
# 	​
#
# =β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X
# i
# 	​
#
# +ε
# i
# 	​
#
#
# We estimate the parameters
# 𝛽
# 0
# β
# 0
# 	​
#
#  and
# 𝛽
# 1
# β
# 1
# 	​
#
#  with
# 𝑏
# 0
# b
# 0
# 	​
#
#  and
# 𝑏
# 1
# b
# 1
# 	​
#
# , such that the following sum of squared errors (SSE) is minimized:
#
# 𝑆
# 𝑆
# 𝐸
# =
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑌
# 𝑖
# −
# 𝑌
# 𝑖
# ^
# )
# 2
# =
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑌
# 𝑖
# −
# 𝑏
# 0
# −
# 𝑏
# 1
# 𝑋
# 𝑖
# )
# 2
# SSE=
# i=1
# ∑
# n
# 	​
#
# (Y
# i
# 	​
#
# −
# Y
# i
# 	​
#
# ^
# 	​
#
# )
# 2
# =
# i=1
# ∑
# n
# 	​
#
# (Y
# i
# 	​
#
# −b
# 0
# 	​
#
# −b
# 1
# 	​
#
# X
# i
# 	​
#
# )
# 2

# %% [markdown]
# Question 6: What is Logistic Regression? How does it differ from Linear Regression?
#
#
# Logistic Regression and Its Difference from Linear Regression
# ##1. What is Logistic Regression?
#
#  - Logistic Regression is a statistical method used to model the relationship between a binary dependent variable (i.e., one that has two possible outcomes) and one or more independent variables.
#
#  - It predicts the probability that a given input belongs to a particular category — typically coded as 1 (success/yes) or 0 (failure/no).
#
# ##Mathematical Form of Logistic Regression
#
#  - Instead of fitting a straight line (like in linear regression), logistic regression fits an S-shaped (sigmoid) curve using the logistic function:
#
# 𝑃
# (
# 𝑌
# =
# 1
# ∣
# 𝑋
# )
# =
# 1
# 1
# +
# 𝑒
# −
# (
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# )
# P(Y=1∣X)=
# 1+e
# −(β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X)
# 1
# 	​
#
#
# Where:
#
# 𝑃
# (
# 𝑌
# =
# 1
# ∣
# 𝑋
# )
# P(Y=1∣X): Probability that
# 𝑌
# Y equals 1 given
# 𝑋
# X
#
# 𝛽
# 0
# β
# 0
# 	​
#
# : Intercept term
#
# 𝛽
# 1
# β
# 1
# 	​
#
# : Coefficient showing how
# 𝑋
# X affects the probability
#
# 𝑒
# e: Base of the natural logarithm (~2.718)
#
# -  2. Purpose of Logistic Regression
#
# Used when the dependent variable is categorical, especially binary (e.g., yes/no, pass/fail, buy/don’t buy).
#
# It estimates the probability of an event occurring, not a continuous value.

# %% [markdown]
# Question 7: Name and briefly describe three common evaluation metrics for regression
# models
#
#  - Three Common Evaluation Metrics for Regression Models
#
# When we build a regression model (like linear regression), we need to measure how well the model fits the data and how accurately it predicts outcomes.
# Here are three widely used evaluation metrics:
#
# ##1. Mean Squared Error (MSE)
# 𝑀
# 𝑆
# 𝐸
# =
# 1
# 𝑛
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑌
# 𝑖
# −
# 𝑌
# 𝑖
# ^
# )
# 2
# MSE=
# n
# 1
# 	​
#
# i=1
# ∑
# n
# 	​
#
# (Y
# i
# 	​
#
# −
# Y
# i
# 	​
#
# ^
# 	​
#
# )
# 2
#
# Meaning: Measures the average squared difference between the actual (
# 𝑌
# 𝑖
# Y
# i
# 	​
#
# ) and predicted (
# 𝑌
# 𝑖
# ^
# Y
# i
# 	​
#
# ^
# 	​
#
# ) values.
#
# Interpretation:
#
# Lower MSE = better model performance.
#
# Squaring the errors penalizes large errors more heavily.
#
# ##2. Root Mean Squared Error (RMSE)
# 𝑅
# 𝑀
# 𝑆
# 𝐸
# =
# 1
# 𝑛
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑌
# 𝑖
# −
# 𝑌
# 𝑖
# ^
# )
# 2
# RMSE=
# n
# 1
# 	​
#
# i=1
# ∑
# n
# 	​
#
# (Y
# i
# 	​
#
# −
# Y
# i
# 	​
#
# ^
# 	​
#
# )
# 2
# 	​
#
#
# Meaning: The square root of MSE — brings the error back to the same units as the dependent variable.
#
# Interpretation:
#
# Easier to interpret than MSE.
#
# Smaller RMSE indicates a better fit and more accurate predictions.
#
# ##3. Coefficient of Determination (
# 𝑅
# 2
# R
# 2
# )
# 𝑅
# 2
# =
# 1
# −
# ∑
# (
# 𝑌
# 𝑖
# −
# 𝑌
# 𝑖
# ^
# )
# 2
# ∑
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# 2
# R
# 2
# =1−
# ∑(Y
# i
# 	​
#
# −
# Y
# ˉ
# )
# 2
# ∑(Y
# i
# 	​
#
# −
# Y
# i
# 	​
#
# ^
# 	​
#
# )
# 2
# 	​
#
#
# Meaning: Represents the proportion of variance in the dependent variable that is explained by the independent variable(s).
#
# Range:
# 0
# ≤
# 𝑅
# 2
# ≤
# 1
# 0≤R
# 2
# ≤1
#
# Interpretation:
#
# 𝑅
# 2
# =
# 1
# R
# 2
# =1: Perfect fit (model explains all variation).
#
# 𝑅
# 2
# =
# 0
# R
# 2
# =0: Model explains no variation in the data.

# %% [markdown]
# Question 8: What is the purpose of the R-squared metric in regression analysis?
#
#  - R-squared (
# 𝑅
# 2
# R
# 2
#  ), also known as the coefficient of determination, is a statistical measure that explains how well the independent variable(s) in a regression model account for the variation in the dependent variable.
#
# It essentially tells us how good the model’s predictions are compared to the actual data.

# %% [markdown]
# Question 9: Write Python code to fit a simple linear regression model using scikit-learn
# and print the slope and intercept.
# (Include your Python code and output in the code box below.
#
#  -

# %%
# Import necessary libraries
from sklearn.linear_model import LinearRegression
import numpy as np

# Sample data
# X = independent variable (e.g., hours studied)
# y = dependent variable (e.g., exam scores)
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # reshape to 2D for sklearn
y = np.array([2, 4, 5, 4, 5])

# Create the model
model = LinearRegression()

# Fit the model to the data
model.fit(X, y)

# Get the slope (coefficient) and intercept
slope = model.coef_[0]
intercept = model.intercept_

# Print results
print("Slope (β₁):", slope)
print("Intercept (β₀):", intercept)
# Out:
# Slope (β₁): 0.6
# Intercept (β₀): 2.2
